# %% [markdown]
# <a href="https://colab.research.google.com/github/ymuto0302/GR_2023/blob/main/GR2023_stats_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 課題1-1：平均と分散
# 次の数値列（１次元データ）は，クラスA, B における数学の得点データである。
# （注意）数値列はリストとして与えられる。
#
# クラスA, B それぞれについて，得点の平均および標準偏差を求めるコードを書け。

# %%
score_A = [72, 78, 68, 71, 80, 90, 88, 95, 85, 75, 60, 50] # クラスAの得点
score_B = [70, 84, 88, 65, 76, 92, 100, 40, 98, 85, 68, 48] # クラスBの得点

# この下にコードを書く

# %% [markdown]
# ## 課題1-2：平均と分散（関数化）
# 上記の「平均および標準偏差を計算する部分」を関数として実装せよ。
# - 引数：数値列（１次データ）
# - 戻り値：平均，標準偏差

# %%
# ここにコードを書く

# %% [markdown]
# ## 課題1-3：平均と分散（numpy の利用）
# 平均や標準偏差などの統計量は，numpy モジュールのメソッドを用いることが簡単に計算できる。
#
# numpy の使い方を調べ，上記のコードを numpy 版に書き換えよ。

# %%
# ここにコードを書く

# %% [markdown]
# ## 課題2-1：線形回帰
# 線形回帰における回帰係数の推定には最小二乗法が用いられる。
# 「ラグビーチーム 20名の選出の身長(x)と体重(y)のデータ」を対象として，回帰係数を求めよ。
#
# （注意）回帰係数の算出には，データの平均，分散，共分散が利用される。これらは numpy のメソッドを用いることを勧める。

# %%
# ラグビーチーム 20名の選出の身長(x)と体重(y)のデータ
data = [(183.2, 76.8), (182.4, 79.5), (179.4, 87.2), (177.4, 74.6),
        (180.4, 77.5), (173.2, 69.0), (182.1, 81.8), (174.7, 80.5),
        (180.7, 80.2), (185.8, 86.5), (181.3, 77.7), (184.0, 85.4),
        (179.3, 76.4), (169.5, 74.5), (176.5, 83.7), (184.2, 85.9),
        (187.7, 89.5), (186.4, 99.8), (177.8, 81.7), (186.5, 75.3)]

# この下にコードを書く

# %% [markdown]
# ## 課題2-2：線形回帰（可視化）
# matplotlib の使い方を調べ，上記の２次元データの散布図および回帰直線を可視化せよ。
#
# 完成イメージは以下のとおり：
# ![kaiki_sample.png](data:image/png;base64,...)

# %%
# ここにコードを書く
